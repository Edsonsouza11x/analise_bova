# %% [markdown]
# <a href="https://colab.research.google.com/github/Edsonsouza11x/analise_bova/blob/main/An%C3%A1lise_A%C3%A7%C3%A3o_BOVA11_SA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise da Ação BOVA11.SA
#
# **Retorno da ação BOVA11.SA desde 2018**
#
# A ação BOVA11.SA, que representa o Índice Bovespa, é um dos principais ativos de renda variável do Brasil. Desde 2018, a ação apresentou um retorno simples de **50,66%**, com uma média de retorno diário de **0,04%** e uma taxa de retorno anual de **10,61%**.
#
# Esse retorno foi impulsionado por uma série de fatores, incluindo a recuperação econômica do Brasil após a crise de 2015-2016, o aumento das taxas de juros e a valorização das commodities.
#
# **Retorno da ação BOVA11.SA em termos logarítmicos**
#
# O retorno logarítmico da ação BOVA11.SA é **40,99%**, com uma média de retorno diário de **0,03%** e uma taxa de retorno anual de **7,16%**.
#
# O retorno logarítmico é uma medida de retorno que leva em consideração o efeito cumulativo do crescimento. Ele é calculado usando a seguinte fórmula:
#
# ```
# R = ln(P2/P1)
# ```
#
# onde:
#
# * R é o retorno logarítmico
# * P2 é o preço final da ação
# * P1 é o preço inicial da ação
#
# O retorno logarítmico é uma medida mais precisa de retorno do que o retorno simples, pois ele leva em consideração o efeito cumulativo do crescimento.
#
# **Conclusão**
#
# A ação BOVA11.SA apresentou um retorno significativo desde 2018. O retorno logarítmico de 40,99% é um resultado positivo, considerando o cenário econômico brasileiro.
#
# No entanto, é importante ressaltar que o mercado de ações é arriscado e o retorno passado não é garantia de retorno futuro.

# %%
# !pip install yfinance

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import yfinance as yf
import plotly.graph_objects as go

# %% [markdown]
# ## Base de dados

# %%
# bova_df = data.DataReader(name = 'BOVA11.SA', data_source='yahoo', start='2018-01-01')
bova_df = yf.download("BOVA11.SA", start='2018-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
bova_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   74.000000   75.230003   74.000000   75.099998   75.099998
# 2018-01-03   75.000000   75.769997   74.900002   75.300003   75.300003
# 2018-01-04   75.540001   76.440002   75.510002   76.000000   76.000000
# 2018-01-05   76.000000   76.440002   75.559998   76.440002   76.440002
# 2018-01-08   76.330002   76.760002   75.930000   76.760002   76.760002
# ...                ...         ...         ...         ...         ...
# 2023-09-25  112.110001  112.570000  111.930000  112.570000  112.570000
# 2023-09-26  111.900002  111.900002  110.650002  110.650002  110.650002
# 2023-09-27  111.500000  111.820000  109.889999  110.699997  110.699997
# 2023-09-28  110.570000  112.410004  110.570000  112.180000  112.180000
# 2023-09-29  113.370003  113.389999  112.300003  113.150002  113.150002
#
#              Volume
# Date
# 2018-01-02  2292470
# 2018-01-03  3765200
# 2018-01-04  2245750
# ...

# %%
bova_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1409 entries, 2018-01-02 to 2023-09-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1409 non-null   float64
#  1   High       1409 non-null   float64
#  2   Low        1409 non-null   float64
#  3   Close      1409 non-null   float64
#  4   Adj Close  1409 non-null   float64
#  5   Volume     1409 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 77.1 KB

# %%
bova_df.head(3)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2018-01-02  74.000000  75.230003  74.000000  75.099998  75.099998  2292470
# 2018-01-03  75.000000  75.769997  74.900002  75.300003  75.300003  3765200
# 2018-01-04  75.540001  76.440002  75.510002  76.000000  76.000000  2245750

# %%
bova_df.tail(3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-09-27  111.500000  111.820000  109.889999  110.699997  110.699997
# 2023-09-28  110.570000  112.410004  110.570000  112.180000  112.180000
# 2023-09-29  113.370003  113.389999  112.300003  113.150002  113.150002
#
#              Volume
# Date
# 2023-09-27  4850443
# 2023-09-28  3948319
# 2023-09-29  4237836

# %%
bova_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1409.000000  1409.000000  1409.000000  1409.000000  1409.000000
# mean     99.337544   100.163549    98.394784    99.286757    99.286757
# std      13.521133    13.512071    13.568290    13.541969    13.541969
# min      62.900002    66.300003    59.099998    61.139999    61.139999
# 25%      91.500000    92.440002    90.550003    91.379997    91.379997
# 50%     101.199997   101.919998   100.150002   101.010002   101.010002
# 75%     109.599998   110.599998   108.750000   109.839996   109.839996
# max     125.570000   126.220001   124.709999   125.750000   125.750000
#
#              Volume
# count  1.409000e+03
# mean   7.033244e+06
# std    4.296964e+06
# min    7.004400e+05
# 25%    4.350500e+06
# 50%    6.110460e+06
# 75%    8.716198e+06
# max    4.584923e+07

# %%
bova_df[bova_df['Close'] >= 125.68]
# Out:
#                   Open        High         Low   Close  Adj Close   Volume
# Date
# 2021-06-07  124.800003  126.220001  124.559998  125.75     125.75  5564011

# %%
bova_df.to_csv('bova.csv')

# %%
bova_df2 = pd.read_csv('/content/bova.csv')
bova_df2
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-01-02   74.000000   75.230003   74.000000   75.099998   75.099998
# 1     2018-01-03   75.000000   75.769997   74.900002   75.300003   75.300003
# 2     2018-01-04   75.540001   76.440002   75.510002   76.000000   76.000000
# 3     2018-01-05   76.000000   76.440002   75.559998   76.440002   76.440002
# 4     2018-01-08   76.330002   76.760002   75.930000   76.760002   76.760002
# ...          ...         ...         ...         ...         ...         ...
# 1404  2023-09-25  112.110001  112.570000  111.930000  112.570000  112.570000
# 1405  2023-09-26  111.900002  111.900002  110.650002  110.650002  110.650002
# 1406  2023-09-27  111.500000  111.820000  109.889999  110.699997  110.699997
# 1407  2023-09-28  110.570000  112.410004  110.570000  112.180000  112.180000
# 1408  2023-09-29  113.370003  113.389999  112.300003  113.150002  113.150002
#
#        Volume
# 0     2292470
# ...

# %% [markdown]
# #Taxa de Retorno Simples

# %%
len(bova_df2)
# Out:
# 1409

# %%
bova_df['Close'][0], bova_df['Close'][len(bova_df) - 1]
# Out:
# (75.0999984741211, 113.1500015258789)

# %%
((bova_df['Close'][len(bova_df) - 1] - bova_df['Close'][0]) / bova_df['Close'][0]) * 100
# Out:
# 50.665784054402565

# %%
(bova_df['Close'][len(bova_df) - 1] / bova_df['Close'][0] - 1) * 100
# Out:
# 50.665784054402565

# %% [markdown]
# #Taxa de Retorno Diária

# %%
bova_df['Close']
# Out:
# Date
# 2018-01-02     75.099998
# 2018-01-03     75.300003
# 2018-01-04     76.000000
# 2018-01-05     76.440002
# 2018-01-08     76.760002
#                  ...
# 2023-09-25    112.570000
# 2023-09-26    110.650002
# 2023-09-27    110.699997
# 2023-09-28    112.180000
# 2023-09-29    113.150002
# Name: Close, Length: 1409, dtype: float64

# %%
bova_df['Close'].shift(1)
# Out:
# Date
# 2018-01-02           NaN
# 2018-01-03     75.099998
# 2018-01-04     75.300003
# 2018-01-05     76.000000
# 2018-01-08     76.440002
#                  ...
# 2023-09-25    112.610001
# 2023-09-26    112.570000
# 2023-09-27    110.650002
# 2023-09-28    110.699997
# 2023-09-29    112.180000
# Name: Close, Length: 1409, dtype: float64

# %%
bova_df['RS Close'] = (bova_df['Close'] / bova_df['Close'].shift(1)) - 1

# %%
bova_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   74.000000   75.230003   74.000000   75.099998   75.099998
# 2018-01-03   75.000000   75.769997   74.900002   75.300003   75.300003
# 2018-01-04   75.540001   76.440002   75.510002   76.000000   76.000000
# 2018-01-05   76.000000   76.440002   75.559998   76.440002   76.440002
# 2018-01-08   76.330002   76.760002   75.930000   76.760002   76.760002
# ...                ...         ...         ...         ...         ...
# 2023-09-25  112.110001  112.570000  111.930000  112.570000  112.570000
# 2023-09-26  111.900002  111.900002  110.650002  110.650002  110.650002
# 2023-09-27  111.500000  111.820000  109.889999  110.699997  110.699997
# 2023-09-28  110.570000  112.410004  110.570000  112.180000  112.180000
# 2023-09-29  113.370003  113.389999  112.300003  113.150002  113.150002
#
#              Volume  RS Close
# Date
# 2018-01-02  2292470       NaN
# 2018-01-03  3765200  0.002663
# ...

# %%
bova_df['RS Close'].plot();

# %%
#Média diária de retorno
bova_df['RS Close'].mean()
# Out:
# 0.00043121765191239664

# %%
bova_df['RS Close'].mean() * 100
# Out:
# 0.04312176519123966

# %% [markdown]
# #Taxa de Retorno Anual

# %%
(bova_df['RS Close'].mean() * 246) * 100
# Out:
# 10.607954237044957

# %% [markdown]
# #Taxa de Retorno Logarítmica

# %%
bova_df['Close'][0],bova_df['Close'][len(bova_df) - 1]
# Out:
# (75.0999984741211, 113.1500015258789)

# %%
np.log(bova_df['Close'][len(bova_df) - 1] / bova_df['Close'][0]) * 100
# Out:
# 40.9893847112871

# %%
bova_df['RL Close'] = np.log(bova_df['Close'] / bova_df['Close'].shift(1))
bova_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   74.000000   75.230003   74.000000   75.099998   75.099998
# 2018-01-03   75.000000   75.769997   74.900002   75.300003   75.300003
# 2018-01-04   75.540001   76.440002   75.510002   76.000000   76.000000
# 2018-01-05   76.000000   76.440002   75.559998   76.440002   76.440002
# 2018-01-08   76.330002   76.760002   75.930000   76.760002   76.760002
# ...                ...         ...         ...         ...         ...
# 2023-09-25  112.110001  112.570000  111.930000  112.570000  112.570000
# 2023-09-26  111.900002  111.900002  110.650002  110.650002  110.650002
# 2023-09-27  111.500000  111.820000  109.889999  110.699997  110.699997
# 2023-09-28  110.570000  112.410004  110.570000  112.180000  112.180000
# 2023-09-29  113.370003  113.389999  112.300003  113.150002  113.150002
#
#              Volume  RS Close  RL Close
# Date
# 2018-01-02  2292470       NaN       NaN
# ...

# %%
bova_df['RL Close'].plot();

# %%
#Média de retorno diária
bova_df['RL Close'].mean()
# Out:
# 0.0002911177891426638

# %%
bova_df['RL Close'].mean() * 100
# Out:
# 0.02911177891426638

# %%
#Média de retorno anual
(bova_df['RL Close'].mean() * 246) * 100
# Out:
# 7.161497612909528

# %%
plt.style.use('seaborn-darkgrid')
plt.figure( figsize=(16, 5) )
plt.title('Análise das ações da BOVA - Fechamento', fontsize=15, loc='left')
plt.plot( bova_df.index, bova_df['Close'] )

plt.xlabel('Período da Cotação')
plt.ylabel('Valor da Ação (R$)');
# Out:
# <ipython-input-33-1a3368f5adc9>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
Media_Movel = bova_df['Close'].rolling(5).mean()
Media_Tendencia = bova_df['Close'].rolling(30).mean()

plt.style.use('seaborn-darkgrid')
plt.figure( figsize=(16, 5) )
plt.title('Análise das ações da BOVA - Fechamento', fontsize=15, loc='left')

plt.plot( bova_df.index, bova_df['Close'] )
plt.plot( bova_df.index, Media_Movel )
plt.plot( bova_df.index, Media_Tendencia )

plt.xlabel('Período da Coração')
plt.ylabel('Valor da Ação (R$)');
# Out:
# <ipython-input-34-72f45b4d0686>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
sns.boxplot( data=bova_df, x='Close')
# Out:
# <Axes: xlabel='Close'>

# %%
Grafico = go.Figure(
    data=[
          go.Candlestick(
              x= bova_df.index,
              open = bova_df['Open'],
              high = bova_df['High'],
              low = bova_df['Low'],
              close = bova_df['Close'],
          )
    ]
)

Grafico.update_layout( xaxis_rangeslider_visible=False )

Grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
